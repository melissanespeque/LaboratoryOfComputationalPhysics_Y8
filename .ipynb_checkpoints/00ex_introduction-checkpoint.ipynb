# %% [markdown]
# 1. The MickeyMouse problem
#
# a) Write a program that prints the numbers from 1 to 100. But for multiples of 3 print `Mickey` instead of the corresponding number and for the multiples of 5 print `Mouse`. For numbers which are multiples of both three and five print `MickeyMouse`
#
# b) Put the result in a tuple and substitute `Mickey` with `Donald` and `Mouse` with `Duck`

# %%
import numpy as np

i = 1
while i <= 100:
    if i%3 == 0 and i%5 == 0:
        print("MickeyMouse")
    elif i%3 == 0:
        print("Mickey")
    elif i%5 == 0:
        print("Mouse")
    else:
        print(i)
    i += 1
# Out:
# 1
# 2
# Mickey
# 4
# Mouse
# Mickey
# 7
# 8
# Mickey
# Mouse
# 11
# Mickey
# 13
# 14
# MickeyMouse
# 16
# 17
# Mickey
# 19
# Mouse
# Mickey
# 22
# 23
# Mickey
# Mouse
# 26
# Mickey
# 28
# 29
# MickeyMouse
# 31
# 32
# Mickey
# 34
# Mouse
# Mickey
# 37
# 38
# Mickey
# Mouse
# 41
# Mickey
# 43
# 44
# MickeyMouse
# 46
# 47
# Mickey
# 49
# Mouse
# Mickey
# 52
# 53
# Mickey
# Mouse
# 56
# Mickey
# 58
# 59
# MickeyMouse
# 61
# 62
# Mickey
# 64
# Mouse
# Mickey
# 67
# 68
# Mickey
# Mouse
# 71
# Mickey
# 73
# 74
# MickeyMouse
# 76
# 77
# Mickey
# 79
# Mouse
# Mickey
# 82
# 83
# Mickey
# Mouse
# 86
# Mickey
# 88
# 89
# MickeyMouse
# 91
# 92
# Mickey
# 94
# Mouse
# Mickey
# 97
# 98
# Mickey
# Mouse

# %%
result = ["MickeyMouse" if i%3==0 and i%5==0 else "Mickey" if i%3==0 else "Mouse" if i%5==0 else i for i in range(101)]
print(result)
# Out:
# ['MickeyMouse', 1, 2, 'Mickey', 4, 'Mouse', 'Mickey', 7, 8, 'Mickey', 'Mouse', 11, 'Mickey', 13, 14, 'MickeyMouse', 16, 17, 'Mickey', 19, 'Mouse', 'Mickey', 22, 23, 'Mickey', 'Mouse', 26, 'Mickey', 28, 29, 'MickeyMouse', 31, 32, 'Mickey', 34, 'Mouse', 'Mickey', 37, 38, 'Mickey', 'Mouse', 41, 'Mickey', 43, 44, 'MickeyMouse', 46, 47, 'Mickey', 49, 'Mouse', 'Mickey', 52, 53, 'Mickey', 'Mouse', 56, 'Mickey', 58, 59, 'MickeyMouse', 61, 62, 'Mickey', 64, 'Mouse', 'Mickey', 67, 68, 'Mickey', 'Mouse', 71, 'Mickey', 73, 74, 'MickeyMouse', 76, 77, 'Mickey', 79, 'Mouse', 'Mickey', 82, 83, 'Mickey', 'Mouse', 86, 'Mickey', 88, 89, 'MickeyMouse', 91, 92, 'Mickey', 94, 'Mouse', 'Mickey', 97, 98, 'Mickey', 'Mouse']

# %% [markdown]
# 2. The swap function
#
# Write a function that swap the values of two input variables x and y (whatever the type). Try to do that also without a temporary variable

# %%
def swap(x,y):
    x,y = y,x
    return(x,y)

print(swap(3,4))
# Out:
# (4, 3)

# %% [markdown]
# 3\. Computing the distance
#
# Write a function that calculates and returns the euclidean distance between two points *u* and *v*, where *u* and *v* are both 2-tuples *(x,y)*. For example, if *u=(3,0)* and *v=(0,4)*, the function should return 5

# %%
def distance(u,v):
    return np.sqrt((v[0]-u[0])**2 + (v[1]-u[1])**2)
u =(3,0)
v = (0,4)
print(distance(u,v))
# Out:
# 5.0

# %% [markdown]
# 4\. Counting letters
#
# Write a program to calculate the number of times each character occurs in a given string *s*. Ignore differneces in capitalization

# %%
s="Write a program that prints the numbers from 1 to 100. \
But for multiples of three print Mickey instead of the number and for the multiples of five print Mouse. \
For numbers which are multiples of both three and five print MickeyMouse"

# %%
s = s.lower()

# %%
print(s)
# Out:
# write a program that prints the numbers from 1 to 100. but for multiples of three print mickey instead of the number and for the multiples of five print mouse. for numbers which are multiples of both three and five print mickeymouse

# %%
result = []
for c in set(s):
    counting = s.count(c)
    result.append((counting, c))
print(result)
# Out:
# [(3, 'd'), (2, 'w'), (9, 'h'), (1, 'g'), (2, 'y'), (2, '.'), (14, 'i'), (41, ' '), (10, 'f'), (22, 'e'), (13, 'o'), (2, '0'), (9, 's'), (2, 'v'), (17, 'r'), (9, 'u'), (10, 'n'), (7, 'a'), (5, 'b'), (6, 'l'), (3, 'c'), (8, 'p'), (2, '1'), (19, 't'), (2, 'k'), (12, 'm')]

# %% [markdown]
# 5\. Isolating the unique
#
# Write a function that determines and count the unique numbers in the list *l*

# %%
l = [36, 45, 58, 3, 74, 96, 64, 45, 31, 10, 24, 19, 33, 86, 99, 18, 63, 70, 85,
 85, 63, 47, 56, 42, 70, 84, 88, 55, 20, 54, 8, 56, 51, 79, 81, 57, 37, 91,
 1, 84, 84, 36, 66, 9, 89, 50, 42, 91, 50, 95, 90, 98, 39, 16, 82, 31, 92, 41,
 45, 30, 66, 70, 34, 85, 94, 5, 3, 36, 72, 91, 84, 34, 87, 75, 53, 51, 20, 89, 51, 20]

# %%
result = []
for i in l:
    if i not in result:
        result.append(i)
print(result)
print(len(result))
# Out:
# [36, 45, 58, 3, 74, 96, 64, 31, 10, 24, 19, 33, 86, 99, 18, 63, 70, 85, 47, 56, 42, 84, 88, 55, 20, 54, 8, 51, 79, 81, 57, 37, 91, 1, 66, 9, 89, 50, 95, 90, 98, 39, 16, 82, 92, 41, 30, 34, 94, 5, 72, 87, 75, 53]
# 54

# %%
lres = []
lres = [i for i in l if i not in lres]
print(lres)
# Out:
# [36, 45, 58, 3, 74, 96, 64, 45, 31, 10, 24, 19, 33, 86, 99, 18, 63, 70, 85, 85, 63, 47, 56, 42, 70, 84, 88, 55, 20, 54, 8, 56, 51, 79, 81, 57, 37, 91, 1, 84, 84, 36, 66, 9, 89, 50, 42, 91, 50, 95, 90, 98, 39, 16, 82, 31, 92, 41, 45, 30, 66, 70, 34, 85, 94, 5, 3, 36, 72, 91, 84, 34, 87, 75, 53, 51, 20, 89, 51, 20]

# %% [markdown]
# 6\. Combination of functions
#
# Write two functions - one that returns the square of a number, and one that returns the cube. Now write a third function that returns the number raised to the 6th power using the two previous functions.

# %%
def sq(x):
    x = x**2
    return x

def cu(x):
    x = x**3
    return x

def third(x):
    x = sq(cu(x))
    return x
    
print(third(123))
# Out:
# 3462825991689

# %% [markdown]
# 7\. Cubes
#
# Create a list of the cubes of x for x in *[0, 10]* using:
#
# a) a for loop
#
# b) a list comprehension

# %%
list = []
for i in range(11):
    i = i**3
    list.append(i)
print(list)
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %%
otherlist = [i**3 for i in range(11)]
print(otherlist)
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %% [markdown]
# 8\. Nested list comprehension
#
# A Pythagorean triple is an integer solution to the Pythagorean theorem $a^2+b^2=c^2$. The first Pythagorean triple is (3,4,5). Find and put in a tuple all unique Pythagorean triples for the positive integers a, b and c less than 100.

# %%
triples = tuple(
    (a, b, c)
    for a in range(1, 100)
    for b in range(a, 100)
    for c in range(b, 100)
    if a**2 + b**2 == c**2
)

print(triples)
# Out:
# ((3, 4, 5), (5, 12, 13), (6, 8, 10), (7, 24, 25), (8, 15, 17), (9, 12, 15), (9, 40, 41), (10, 24, 26), (11, 60, 61), (12, 16, 20), (12, 35, 37), (13, 84, 85), (14, 48, 50), (15, 20, 25), (15, 36, 39), (16, 30, 34), (16, 63, 65), (18, 24, 30), (18, 80, 82), (20, 21, 29), (20, 48, 52), (21, 28, 35), (21, 72, 75), (24, 32, 40), (24, 45, 51), (24, 70, 74), (25, 60, 65), (27, 36, 45), (28, 45, 53), (30, 40, 50), (30, 72, 78), (32, 60, 68), (33, 44, 55), (33, 56, 65), (35, 84, 91), (36, 48, 60), (36, 77, 85), (39, 52, 65), (39, 80, 89), (40, 42, 58), (40, 75, 85), (42, 56, 70), (45, 60, 75), (48, 55, 73), (48, 64, 80), (51, 68, 85), (54, 72, 90), (57, 76, 95), (60, 63, 87), (65, 72, 97))

# %% [markdown]
# 9\. Normalization
#
# Write a function that takes a tuple of numbers and returns it with the entries normalized to one

# %%
def((a))

# %%
#1.a) Write a program that prints the numbers from 1 to 100. But for multiples of 3 print Mickey instead 
#of the corresponding number and for the multiples of 5 print Mouse. 
#For numbers which are multiples of both three and five print MickeyMouse
x = 1
while x <= 100:
    if x % 3 == 0 and x % 5 == 0:
        print("MickeyMouse")
    elif x % 3 == 0:
        print("Mickey")
    elif x % 5 == 0:
        print("Mouse")
    else:
        print(x)
    x += 1
#tem que incrementar no final, depois de checar tudo
# Out:
# 1
# 2
# Mickey
# 4
# Mouse
# Mickey
# 7
# 8
# Mickey
# Mouse
# 11
# Mickey
# 13
# 14
# MickeyMouse
# 16
# 17
# Mickey
# 19
# Mouse
# Mickey
# 22
# 23
# Mickey
# Mouse
# 26
# Mickey
# 28
# 29
# MickeyMouse
# 31
# 32
# Mickey
# 34
# Mouse
# Mickey
# 37
# 38
# Mickey
# Mouse
# 41
# Mickey
# 43
# 44
# MickeyMouse
# 46
# 47
# Mickey
# 49
# Mouse
# Mickey
# 52
# 53
# Mickey
# Mouse
# 56
# Mickey
# 58
# 59
# MickeyMouse
# 61
# 62
# Mickey
# 64
# Mouse
# Mickey
# 67
# 68
# Mickey
# Mouse
# 71
# Mickey
# 73
# 74
# MickeyMouse
# 76
# 77
# Mickey
# 79
# Mouse
# Mickey
# 82
# 83
# Mickey
# Mouse
# 86
# Mickey
# 88
# 89
# MickeyMouse
# 91
# 92
# Mickey
# 94
# Mouse
# Mickey
# 97
# 98
# Mickey
# Mouse

# %%
#1.b) Put the result in a tuple and substitute Mickey with Donald and Mouse with Duck
x = 1
results_list = []

while x <= 100:
    if x % 3 == 0 and x % 5 == 0:
        results_list.append("MickeyMouse")
    elif x % 3 == 0:
        results_list.append("Mickey")
    elif x % 5 == 0:
        results_list.append("Mouse")
    else:
        results_list.append(x)
    x += 1

# convert list to tuple
results_list = [
    item.replace("Mickey", "Donald").replace("Mouse", "Duck") if isinstance(item, str) else item
    for item in results_list
]
results = tuple(results_list)
results
# Out:
# (1,
#  2,
#  'Donald',
#  4,
#  'Duck',
#  'Donald',
#  7,
#  8,
#  'Donald',
#  'Duck',
#  11,
#  'Donald',
#  13,
#  14,
#  'DonaldDuck',
#  16,
#  17,
#  'Donald',
#  19,
#  'Duck',
#  'Donald',
#  22,
#  23,
#  'Donald',
#  'Duck',
#  26,
#  'Donald',
#  28,
#  29,
#  'DonaldDuck',
#  31,
#  32,
#  'Donald',
#  34,
#  'Duck',
#  'Donald',
#  37,
#  38,
#  'Donald',
#  'Duck',
#  41,
#  'Donald',
#  43,
#  44,
#  'DonaldDuck',
#  46,
#  47,
#  'Donald',
#  49,
#  'Duck',
#  'Donald',
#  52,
#  53,
#  'Donald',
#  'Duck',
#  56,
#  'Donald',
#  58,
#  59,
#  'DonaldDuck',
#  61,
#  62,
#  'Donald',
#  64,
#  'Duck',
#  'Donald',
#  67,
#  68,
#  'Donald',
#  'Duck',
#  71,
#  'Donald',
#  73,
#  74,
#  'DonaldDuck',
#  76,
#  77,
#  'Donald',
#  79,
#  'Duck',
#  'Donald',
#  82,
#  83,
#  'Donald',
#  'Duck',
#  86,
#  'Donald',
#  88,
#  89,
#  'DonaldDuck',
#  91,
#  92,
#  'Donald',
#  94,
#  'Duck',
#  'Donald',
#  97,
#  98,
#  'Donald',
#  'Duck')

# %%
#2. Write a function that swap the values of two input variables x and y (whatever the type). Try to do that also without a temporary variable
def swap(x,y):
    x, y = y, x
    return x,y
swap(3,4)
# Out:
# (4, 3)

# %%
#3. Write a function that calculates and returns the euclidean distance between two points u and v, where u and v are both 2-tuples (x,y).
#For example, if u=(3,0) and v=(0,4), the function should return 5
u=(3,0)
v=(0,4)
def distance(u,v):
    d = ((u[0]-u[1])**2+((v[0]-v[1])**2))**(1/2)
    print(d)
distance(u,v)
# Out:
# 5.0

# %%
#4.Write a program to calculate the number of times each character occurs in a given string s. Ignore differneces in capitalization
s="Write a program that prints the numbers from 1 to 100. \
But for multiples of three print Mickey instead of the number and for the multiples of five print Mouse. \
For numbers which are multiples of both three and five print MickeyMouse"

s = s.lower()  # ignore capitalization

#Cria um dicionário vazio
char_count = {}

#cria um loop ed cada char em S
#Em Python, !!!strings são iteráveis!!!!
for char in s:
    #Verifica se o caractere já foi visto antes, se sim: incrementa 1, se não, add o char=1
    if char in char_count:
        char_count[char] += 1
    else:
        char_count[char] = 1

print(char_count)
# Out:
# {'w': 2, 'r': 17, 'i': 14, 't': 19, 'e': 22, ' ': 41, 'a': 7, 'p': 8, 'o': 13, 'g': 1, 'm': 12, 'h': 9, 'n': 10, 's': 9, 'u': 9, 'b': 5, 'f': 10, '1': 2, '0': 2, '.': 2, 'l': 6, 'c': 3, 'k': 2, 'y': 2, 'd': 3, 'v': 2}

# %%
#5. Write a function that determines and count the unique numbers in the list l
l = [36, 45, 58, 3, 74, 96, 64, 45, 31, 10, 24, 19, 33, 86, 99, 18, 63, 70, 85,
 85, 63, 47, 56, 42, 70, 84, 88, 55, 20, 54, 8, 56, 51, 79, 81, 57, 37, 91,
 1, 84, 84, 36, 66, 9, 89, 50, 42, 91, 50, 95, 90, 98, 39, 16, 82, 31, 92, 41,
 45, 30, 66, 70, 34, 85, 94, 5, 3, 36, 72, 91, 84, 34, 87, 75, 53, 51, 20, 89, 51, 20]

result = []
for num in l:
    if num not in result:
        #crio uma lista com todos os numeros unicos
        result.append(num)
#para saber a qt, ou 'tamanho', posso só criar a lista de depois usar o lenght        
print(result,len(result))
# Out:
# [36, 45, 58, 3, 74, 96, 64, 31, 10, 24, 19, 33, 86, 99, 18, 63, 70, 85, 47, 56, 42, 84, 88, 55, 20, 54, 8, 51, 79, 81, 57, 37, 91, 1, 66, 9, 89, 50, 95, 90, 98, 39, 16, 82, 92, 41, 30, 34, 94, 5, 72, 87, 75, 53] 54

# %%
#6.Write two functions - one that returns the square of a number, and one that returns the cube. 
#Now write a third function that returns the number raised to the 6th power using the two previous functions.

def sqr(x):
    x = x**2
    return x

def cube(x):
    x = x**3
    return x

def comb(x):
    return sqr(cube(x))
    #composição de funções
x = 2
comb(x)
# Out:
# 64

# %%
#7. Create a list of the cubes of x for x in [0, 10] using:
#a) a for loop
result = []

for x in range(0,11):
    cube = x**3
    result.append(cube)

#b) a list comprehension
#primeiro escreve a função, define q é uma lista, depois o for loop
results = [x**3 for x in range(0,11)]

print(result,results)
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000] [0, 1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %%
#8.A Pythagorean triple is an integer solution to the Pythagorean theorem c^2 = a^2+b^2. (Nested list comprehension)
#The first Pythagorean triple is (3,4,5). Find and put in a tuple all unique Pythagorean triples for the positive integers a, b and c less than 100.

#list comprehension: [expressão for ... for ... if condição]

#cria a lista de triples considerando-se a < b < c pra satisfazer a condição pitagórica
triples = [
    (a, b, c)
#a assume valores de 1 até 99 (a representa o primeiro cateto)
    for a in range(1, 100)
#b começa em a + 1; Garante b > a; Evita duplicatas como (4,3,5) 
    for b in range(a + 1, 100)
#c começa em b + 1; Garante c > b; c é a hipotenusa
    for c in range(b + 1, 100)
#equacao de pitagoras
    if a*a + b*b == c*c
]

#transforma a lista (mutavel) numa tupla (imutavel)
triples = tuple(triples)
print(triples)
# Out:
# ((3, 4, 5), (5, 12, 13), (6, 8, 10), (7, 24, 25), (8, 15, 17), (9, 12, 15), (9, 40, 41), (10, 24, 26), (11, 60, 61), (12, 16, 20), (12, 35, 37), (13, 84, 85), (14, 48, 50), (15, 20, 25), (15, 36, 39), (16, 30, 34), (16, 63, 65), (18, 24, 30), (18, 80, 82), (20, 21, 29), (20, 48, 52), (21, 28, 35), (21, 72, 75), (24, 32, 40), (24, 45, 51), (24, 70, 74), (25, 60, 65), (27, 36, 45), (28, 45, 53), (30, 40, 50), (30, 72, 78), (32, 60, 68), (33, 44, 55), (33, 56, 65), (35, 84, 91), (36, 48, 60), (36, 77, 85), (39, 52, 65), (39, 80, 89), (40, 42, 58), (40, 75, 85), (42, 56, 70), (45, 60, 75), (48, 55, 73), (48, 64, 80), (51, 68, 85), (54, 72, 90), (57, 76, 95), (60, 63, 87), (65, 72, 97))

# %%
#9. Write a function that takes a tuple of numbers and returns it with the entries normalized to one

def normalize(numbers):
    min_val = min(numbers)
    max_val = max(numbers)

    normalized = tuple(
        (x - min_val) / (max_val - min_val)
        for x in numbers
    )

    return normalized

numbers = (1,2,32,46,8,3,100,34)
normalize(numbers)
# Out:
# (0.0,
#  0.010101010101010102,
#  0.31313131313131315,
#  0.45454545454545453,
#  0.0707070707070707,
#  0.020202020202020204,
#  1.0,
#  0.3333333333333333)
