# %% [markdown]
# ### CNNs applied to time series

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D

# %run plot.py

# %% [markdown]
# ### Read data

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000.dat'
fnamex='DATA/x_'+str0
fnamey='DATA/y_'+str0

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
# number of samples, number of features
N,L = len(x), len(x[0])

Show_data(x,L,"original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)

y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1. # y contains one-hot encoding
# Out:
# data:  10000

# %% [markdown]
# ### Split train-validation and rescale

# %%
# split into training and validation sets
perc_train=0.8
N_train = int(perc_train*N)
x_train = x[:N_train]
print(x_train.shape)
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]
N_val = len(x_val)
print('N_train=',N_train,'  N_val=',N_val,'  L=',L,'  n_class=',n_class)

 
#remove average value of each sample from its values
xm_train = x_train.mean(axis=1)
std_train = x_train.std(axis=1)
xm_val = x_val.mean(axis=1)
std_val = x_val.std(axis=1)
print('std_train average and mean:',max(std_train), min(std_train), std_train.mean(axis=0))
print('std_val average and mean:',max(std_val), min(std_val), std_val.mean(axis=0))

# rescale with variance on the training set
for i in range(N_train):
    #x_train[i] = (x_train[i]-xm_train[i])/ std_train[i] #not good, std_train is very variable across samples
     #x_train[i] = (x_train[i]-xm_train[i])/ 400 #crude rescaling, variance should be used
     x_train[i] = (x_train[i]-xm_train[i])/ std_train.mean(axis=0)
for i in range(N_val):
    #x_val[i] = (x_val[i]-xm_val[i])/ std_val[i]
    #x_val[i] = (x_val[i]-xm_val[i])/ 400
    x_val[i] = (x_val[i]-xm_val[i])/ std_val.mean(axis=0)
#

    
Show_data(x_train,L,"rescaled train data")
Show_data(x_val,L,"rescaled validation data")

#x_train=x_train.astype("float32")
#y_train=y_train.astype("float32")
#x_val=x_val.astype("float32")
#y_val=y_val.astype("float32")

# Keras wants an additional dimension with a 1 at the end
x_train = x_train.reshape(x_train.shape[0], L, 1)
x_val =  x_val.reshape(x_val.shape[0], L, 1)
input_shape = (L, 1) # number of features, number of channels (1 for 1D data)

###data is normalized - by the mean : fixed number over the whole dataset
# Out:
# (8000, 60)
# N_train= 8000   N_val= 2000   L= 60   n_class= 3
# std_train average and mean: 588.25397835931 44.84287073276593 201.46657645528722
# std_val average and mean: 569.9090424503428 55.06717110341998 201.92178219610327

# %% [markdown]
# ## Convolutional NN

# %%
# ...LESSON ...
# reproducibility
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

## from keras import regularizers, initializers

reg = tf.keras.regularizers.l2(0.0001) ## raised to 0.2 the regularization strenghts
#reg = regularizers.l1(0.1)
ini = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, 
                                        seed=None)
NCONV = 1 #swtich between 1 and 2 CNNs
NF = 5 #number of filters

# challenge: at most 600 tunable parameters
model = Sequential()
# 
if NCONV==1:
    # -----2-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg,
                     activation='relu', 
                     input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Conv1D(filters=5, kernel_size=7, 
                     activation='relu'))
    model.add(Flatten())
    model.add(Dense(12, activation='relu'))
    model.add(Dropout(0.2))
# 
if NCONV==2:
    # -----1-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg, ######## TRY WITHOUT !
                     activation='relu', input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Flatten())
    model.add(Dense(9, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(6, activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(10, activation='relu'))
    #model.add(Dropout(0.3))
model.add(Dense(n_class, activation='softmax')) # softmax !

print('----- Model',NCONV,'-----')
print(model.summary())

# optimizers
# .SGD(lr=0.01, momentum=0.9, nesterov=True) # decay=1e-6,
# .RMSprop()
# .Nadam()
opt = tf.keras.optimizers.Adam()

# compile the model
# categorical_crossentropy, 3 output nodes
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=opt,metrics=['accuracy'])
# Out:
# ----- Model 1 -----
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_4 (Conv1D)               │ (None, 50, 5)          │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling1d_2             │ (None, 10, 5)          │             0 │
# │ (AveragePooling1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 4, 5)           │           180 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 12)             │           252 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │            39 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 531 (2.07 KB)
#  Trainable params: 531 (2.07 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
model.layers
# Out:
# [<Conv1D name=conv1d_4, built=True>,
#  <AveragePooling1D name=average_pooling1d_2, built=True>,
#  <Conv1D name=conv1d_5, built=True>,
#  <Flatten name=flatten_2, built=True>,
#  <Dense name=dense_4, built=True>,
#  <Dropout name=dropout_2, built=True>,
#  <Dense name=dense_5, built=True>]

# %%
def Show_weights(model,l=0,label="model"):
    c=['r','y','c','b','m']
    m=['o','s','D','<','>']
    ms=10
    
    w = model.layers[l].get_weights()[0] # weights
    print(w.shape)
    wT=w.T
    print(wT.shape)
    M=len(wT)
    b = model.layers[l].get_weights()[1] # bias
    
    fig,AX=plt.subplots(1,2,figsize=(12,4.4))
    ax=AX[0]
    ax.axhline(0, c="k")
    ax.plot((0,))
    for i in range(M):
        ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
    ax.set_title(label+': filters of layer '+str(l))
    ax.set_xlabel('index')
    ax=AX[1]
    ax.axhline(0, c="k")
    for i in range(M):
        ax.plot((i),(b[i]),c=c[i],marker=m[i],label="filter "+str(i),markersize=ms)
    ax.set_title(label+': bias of layer '+str(l))
    ax.set_xlabel('filter nr')
    ax.set_xticks(np.arange(5))
    ax.legend()
    plt.show()
    
Show_weights(model,0)
Show_weights(model,2)
# Out:
# (11, 1, 5)
# (5, 1, 11)
# (7, 5, 5)
# (5, 5, 7)

# %%
# ...LESSON ...
# Hyper-parameters
# with small minibatch it does not converge!! 
BATCH_SIZE = 200
EPOCHS = 150

print('----- Model ',NCONV,'-----\nFITTING....')
fit = model.fit(x_train,y_train,batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                validation_data=(x_val, y_val),
                verbose=2, shuffle=True)
# Out:
# ----- Model  1 -----
# FITTING....
# Epoch 1/150
# 40/40 - 2s - 52ms/step - accuracy: 0.4125 - loss: 1.0818 - val_accuracy: 0.4005 - val_loss: 1.0659
# Epoch 2/150
# 40/40 - 0s - 6ms/step - accuracy: 0.4594 - loss: 1.0350 - val_accuracy: 0.4935 - val_loss: 1.0001
# Epoch 3/150
# 40/40 - 0s - 6ms/step - accuracy: 0.5815 - loss: 0.9471 - val_accuracy: 0.6300 - val_loss: 0.8915
# Epoch 4/150
# 40/40 - 0s - 6ms/step - accuracy: 0.6716 - loss: 0.8326 - val_accuracy: 0.7515 - val_loss: 0.7481
# Epoch 5/150
# 40/40 - 0s - 6ms/step - accuracy: 0.7607 - loss: 0.6844 - val_accuracy: 0.8315 - val_loss: 0.5672
# Epoch 6/150
# 40/40 - 0s - 6ms/step - accuracy: 0.8179 - loss: 0.5369 - val_accuracy: 0.8770 - val_loss: 0.4245
# Epoch 7/150
# 40/40 - 0s - 6ms/step - accuracy: 0.8515 - loss: 0.4375 - val_accuracy: 0.8975 - val_loss: 0.3420
# Epoch 8/150
# 40/40 - 0s - 7ms/step - accuracy: 0.8733 - loss: 0.3743 - val_accuracy: 0.9055 - val_loss: 0.2938
# Epoch 9/150
# 40/40 - 0s - 7ms/step - accuracy: 0.8844 - loss: 0.3389 - val_accuracy: 0.9080 - val_loss: 0.2645
# Epoch 10/150
# 40/40 - 0s - 6ms/step - accuracy: 0.8978 - loss: 0.3079 - val_accuracy: 0.9155 - val_loss: 0.2428
# Epoch 11/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9043 - loss: 0.2917 - val_accuracy: 0.9205 - val_loss: 0.2290
# Epoch 12/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9161 - loss: 0.2673 - val_accuracy: 0.9250 - val_loss: 0.2154
# Epoch 13/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9160 - loss: 0.2535 - val_accuracy: 0.9275 - val_loss: 0.2047
# Epoch 14/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9181 - loss: 0.2476 - val_accuracy: 0.9310 - val_loss: 0.1969
# Epoch 15/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9201 - loss: 0.2372 - val_accuracy: 0.9330 - val_loss: 0.1887
# Epoch 16/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9265 - loss: 0.2201 - val_accuracy: 0.9380 - val_loss: 0.1814
# Epoch 17/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9330 - loss: 0.2143 - val_accuracy: 0.9390 - val_loss: 0.1747
# Epoch 18/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9339 - loss: 0.2078 - val_accuracy: 0.9380 - val_loss: 0.1695
# Epoch 19/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9355 - loss: 0.1987 - val_accuracy: 0.9395 - val_loss: 0.1645
# Epoch 20/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9369 - loss: 0.1945 - val_accuracy: 0.9405 - val_loss: 0.1604
# Epoch 21/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9391 - loss: 0.1897 - val_accuracy: 0.9440 - val_loss: 0.1557
# Epoch 22/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9413 - loss: 0.1835 - val_accuracy: 0.9430 - val_loss: 0.1521
# Epoch 23/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9420 - loss: 0.1752 - val_accuracy: 0.9460 - val_loss: 0.1492
# Epoch 24/150
# 40/40 - 0s - 6ms/step - accuracy: 0.
150
# 40/40 - 0s - 6ms/step - accuracy: 0.9835 - loss: 0.0544 - val_accuracy: 0.9750 - val_loss: 0.0755
# Epoch 150/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9847 - loss: 0.0528 - val_accuracy: 0.9750 - val_loss: 0.0751

# %%
def Show_history(fit):
    fig,AX=plt.subplots(1,2,figsize=(10,4.))
    ax=AX[0] 
    ax.plot(fit.history['accuracy'],"b",label="train")
    ax.plot(fit.history['val_accuracy'],"r--",label="valid.")
    ax.plot((0,EPOCHS),(1/3,1/3),":",c="gray",label="random choice")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1])
    ax.legend()
    ax=AX[1]
    ax.plot(fit.history['loss'],"b",label="train")
    ax.plot(fit.history['val_loss'],"r--",label="valid.")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.set_ylim([0, 1.05*np.max(fit.history['loss'])])
    ax.legend()
    plt.show()
Show_history(fit)
Show_weights(model,0)
Show_weights(model,2)
# Out:
# (11, 1, 5)
# (5, 1, 11)
# (7, 5, 5)
# (5, 5, 7)

# %%
# ...LESSON ...
reg2 = tf.keras.regularizers.l1(0.0001)
model2 = keras.models.clone_model(model)
model2.layers[0].kernel_regularizer = reg2
model2.layers[2].kernel_regularizer = reg2
opt2 = tf.keras.optimizers.Adam()   # NEW optimizer instance
model2.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt2,metrics=['accuracy'])

BATCH_SIZE2 = 200
EPOCHS2 = 150

fit2 = model2.fit(x_train,y_train,batch_size=BATCH_SIZE2,epochs=EPOCHS2,
                validation_data=(x_val, y_val), verbose=2, shuffle=True)
# Out:
# Epoch 1/150
# 40/40 - 3s - 72ms/step - accuracy: 0.3900 - loss: 1.0623 - val_accuracy: 0.4020 - val_loss: 1.0304
# Epoch 2/150
# 40/40 - 1s - 16ms/step - accuracy: 0.4890 - loss: 0.9879 - val_accuracy: 0.5835 - val_loss: 0.9374
# Epoch 3/150
# 40/40 - 0s - 6ms/step - accuracy: 0.6373 - loss: 0.8917 - val_accuracy: 0.7110 - val_loss: 0.8358
# Epoch 4/150
# 40/40 - 0s - 6ms/step - accuracy: 0.7203 - loss: 0.7960 - val_accuracy: 0.7730 - val_loss: 0.7252
# Epoch 5/150
# 40/40 - 0s - 7ms/step - accuracy: 0.7836 - loss: 0.6870 - val_accuracy: 0.8225 - val_loss: 0.6046
# Epoch 6/150
# 40/40 - 0s - 7ms/step - accuracy: 0.8161 - loss: 0.5795 - val_accuracy: 0.8735 - val_loss: 0.4825
# Epoch 7/150
# 40/40 - 0s - 9ms/step - accuracy: 0.8518 - loss: 0.4781 - val_accuracy: 0.8945 - val_loss: 0.3753
# Epoch 8/150
# 40/40 - 0s - 8ms/step - accuracy: 0.8731 - loss: 0.3949 - val_accuracy: 0.9020 - val_loss: 0.3075
# Epoch 9/150
# 40/40 - 0s - 9ms/step - accuracy: 0.8871 - loss: 0.3452 - val_accuracy: 0.9145 - val_loss: 0.2691
# Epoch 10/150
# 40/40 - 0s - 10ms/step - accuracy: 0.8905 - loss: 0.3187 - val_accuracy: 0.9220 - val_loss: 0.2440
# Epoch 11/150
# 40/40 - 0s - 11ms/step - accuracy: 0.
150
# 40/40 - 0s - 10ms/step - accuracy: 0.9843 - loss: 0.0503 - val_accuracy: 0.9790 - val_loss: 0.0594
# Epoch 133/150
# 40/40 - 0s - 10ms/step - accuracy: 0.9859 - loss: 0.0480 - val_accuracy: 0.9785 - val_loss: 0.0600
# Epoch 134/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9851 - loss: 0.0511 - val_accuracy: 0.9790 - val_loss: 0.0585
# Epoch 135/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9845 - loss: 0.0490 - val_accuracy: 0.9790 - val_loss: 0.0590
# Epoch 136/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9859 - loss: 0.0450 - val_accuracy: 0.9795 - val_loss: 0.0592
# Epoch 137/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9858 - loss: 0.0498 - val_accuracy: 0.9785 - val_loss: 0.0605
# Epoch 138/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9855 - loss: 0.0456 - val_accuracy: 0.9790 - val_loss: 0.0593
# Epoch 139/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9861 - loss: 0.0462 - val_accuracy: 0.9800 - val_loss: 0.0595
# Epoch 140/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9854 - loss: 0.0488 - val_accuracy: 0.9795 - val_loss: 0.0594
# Epoch 141/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9860 - loss: 0.0463 - val_accuracy: 0.9800 - val_loss: 0.0586
# Epoch 142/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9864 - loss: 0.0484 - val_accuracy: 0.9795 - val_loss: 0.0600
# Epoch 143/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9856 - loss: 0.0485 - val_accuracy: 0.9800 - val_loss: 0.0580
# Epoch 144/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9859 - loss: 0.0484 - val_accuracy: 0.9795 - val_loss: 0.0586
# Epoch 145/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.0455 - val_accuracy: 0.9805 - val_loss: 0.0583
# Epoch 146/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9859 - loss: 0.0475 - val_accuracy: 0.9790 - val_loss: 0.0581
# Epoch 147/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9852 - loss: 0.0451 - val_accuracy: 0.9795 - val_loss: 0.0592
# Epoch 148/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9860 - loss: 0.0481 - val_accuracy: 0.9805 - val_loss: 0.0594
# Epoch 149/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9855 - loss: 0.0450 - val_accuracy: 0.9805 - val_loss: 0.0577
# Epoch 150/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9862 - loss: 0.0461 - val_accuracy: 0.9800 - val_loss: 0.0593

# %%
Show_history(fit)
Show_history(fit2)
Show_weights(model2,0,label="model2")
Show_weights(model2,2,label="model2")
# Out:
# (11, 1, 5)
# (5, 1, 11)
# (7, 5, 5)
# (5, 5, 7)

# %%
# confusion table: compare true labels with predicted ones
import pandas as pd
from scipy import stats

import seaborn 
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn import preprocessing

LABELS = ["absent","positive","negative"] # from labels y 
cmap="GnBu"

def show_confusion_matrix(validations, predictions, label="Model"):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    seaborn.heatmap(matrix,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d',
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title(label+': Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_val = model.predict(x_val)
y_pred_val2 = model2.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)
max_y_pred_val2 = np.argmax(y_pred_val2, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val)
show_confusion_matrix(max_y_val, max_y_pred_val2, label="Model 2")

#print(classification_report(max_y_val, max_y_pred_val))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
